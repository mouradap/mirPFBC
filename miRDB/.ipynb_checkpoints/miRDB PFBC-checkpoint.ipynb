# %% [markdown]
# # microRNAs and Primary Familial Brain Calcification
# ## Denis Arthur Pinheiro de Moura¹
# ### 1 - Laboratório de Imunopatologia Keizo Asami, Universidade Federal de Pernambuco
# <br>
# This project aims to identify microRNAs that target simultaneously more than two PFBC-causing genes.<br>
# Our general hypothesis is that calcification process might be regulated by microRNAs. <br>
# Thus, our specific hypothesis is that identifying the potential microRNAs that regulate more than one PFBC-causing gene at the same time may lead to the understanding of one regulatory mechanism of PFBC.<br><br>
# In order to test these hypotheses, I have extracted data from the <a href='http://www.mirdb.org/index.html'>miRDB database</a> (Wong and Wang, 2015; Liu and Wang, 2019) regarding microRNAs that bind to each of the six PFBC-causing genes (SLC20A2, PDGFB, PDGFRB, XPR1, JAM2 and MYORG).<br><br>
# I have combined each list of microRNAs with its reported Target Score in an one-by-one table. Then, I have created a microRNA selection criteria of an average Target Score between both genes of at least 80, to select potential microRNAs involved with the regulation of both genes.<br>
# In result, I have filtered 17 different microRNAs that may be considered for testing its role on regulating PFBC-causing genes and the calcification process.

# %%
import pandas as pd
import numpy as np

# %%
slc20a2 = pd.read_html('miRDBslc20a2.html')[0]

# %%
slc20a2.columns = slc20a2.iloc[0]

# %%
slc20a2 = slc20a2[1:]

# %%
slc20a2.head()
# Out:
# 0 Target Detail Target Rank Target Score       miRNA Name Gene Symbol  \
# 1       Details           1           99   hsa-miR-144-3p     SLC20A2
# 2       Details           2           99  hsa-miR-3613-3p     SLC20A2
# 3       Details           3           98     hsa-miR-3924     SLC20A2
# 4       Details           4           97   hsa-miR-101-3p     SLC20A2
# 5       Details           5           97    hsa-miR-12129     SLC20A2
#
# 0                   Gene Description
# 1  solute carrier family 20 member 2
# 2  solute carrier family 20 member 2
# 3  solute carrier family 20 member 2
# 4  solute carrier family 20 member 2
# 5  solute carrier family 20 member 2

# %%
pdgfb = pd.read_html('miRDBpdgfb.html')[0]
pdgfb.columns = pdgfb.iloc[0]
pdgfb = pdgfb[1:]
pdgfb.head()
# Out:
# 0 Target Detail Target Rank Target Score       miRNA Name Gene Symbol  \
# 1       Details           1           99  hsa-miR-6867-5p       PDGFB
# 2       Details           2           95     hsa-miR-4451       PDGFB
# 3       Details           3           94  hsa-miR-6851-5p       PDGFB
# 4       Details           4           94    hsa-miR-3689d       PDGFB
# 5       Details           5           93  hsa-miR-3120-3p       PDGFB
#
# 0                          Gene Description
# 1  platelet derived growth factor subunit B
# 2  platelet derived growth factor subunit B
# 3  platelet derived growth factor subunit B
# 4  platelet derived growth factor subunit B
# 5  platelet derived growth factor subunit B

# %%
pdgfrb = pd.read_html('miRDBpdgfrb.html')[0]
pdgfrb.columns = pdgfrb.iloc[0]
pdgfrb = pdgfrb[1:]
pdgfrb.head()
# Out:
# 0 Target Detail Target Rank Target Score       miRNA Name Gene Symbol  \
# 1       Details           1           96  hsa-miR-6764-5p      PDGFRB
# 2       Details           2           95     hsa-miR-4456      PDGFRB
# 3       Details           3           93  hsa-miR-1915-3p      PDGFRB
# 4       Details           4           92     hsa-miR-9-5p      PDGFRB
# 5       Details           5           91  hsa-miR-6804-5p      PDGFRB
#
# 0                              Gene Description
# 1  platelet derived growth factor receptor beta
# 2  platelet derived growth factor receptor beta
# 3  platelet derived growth factor receptor beta
# 4  platelet derived growth factor receptor beta
# 5  platelet derived growth factor receptor beta

# %%
xpr1 = pd.read_html('miRDBxpr1.html')[0]
xpr1.columns = xpr1.iloc[0]
xpr1 = xpr1[1:]
xpr1.head()
# Out:
# 0 Target Detail Target Rank Target Score        miRNA Name Gene Symbol  \
# 1       Details           1           99   hsa-miR-1252-5p        XPR1
# 2       Details           2           98      hsa-miR-2054        XPR1
# 3       Details           3           97     hsa-miR-5692a        XPR1
# 4       Details           4           97  hsa-miR-548at-5p        XPR1
# 5       Details           5           96    hsa-miR-30d-5p        XPR1
#
# 0                                 Gene Description
# 1  xenotropic and polytropic retrovirus receptor 1
# 2  xenotropic and polytropic retrovirus receptor 1
# 3  xenotropic and polytropic retrovirus receptor 1
# 4  xenotropic and polytropic retrovirus receptor 1
# 5  xenotropic and polytropic retrovirus receptor 1

# %%
jam2 = pd.read_html('miRDBjam2.html')[0]
jam2.columns = jam2.iloc[0]
jam2 = jam2[1:]
jam2.head()
# Out:
# 0 Target Detail Target Rank Target Score        miRNA Name Gene Symbol  \
# 1       Details           1           95   hsa-miR-514a-3p        JAM2
# 2       Details           2           95   hsa-miR-514b-3p        JAM2
# 3       Details           3           93      hsa-miR-1205        JAM2
# 4       Details           4           93   hsa-miR-7114-5p        JAM2
# 5       Details           5           93  hsa-miR-10394-5p        JAM2
#
# 0                Gene Description
# 1  junctional adhesion molecule 2
# 2  junctional adhesion molecule 2
# 3  junctional adhesion molecule 2
# 4  junctional adhesion molecule 2
# 5  junctional adhesion molecule 2

# %%
myorg = pd.read_html('miRDBmyorg.html')[0]
myorg.columns = myorg.iloc[0]
myorg = myorg[1:]
myorg.head()
# Out:
# 0 Target Detail Target Rank Target Score        miRNA Name Gene Symbol  \
# 1       Details           1           99   hsa-miR-7110-3p       MYORG
# 2       Details           2           99      hsa-miR-4269       MYORG
# 3       Details           3           99  hsa-miR-6715b-5p       MYORG
# 4       Details           4           96    hsa-miR-218-5p       MYORG
# 5       Details           5           95     hsa-miR-12127       MYORG
#
# 0                              Gene Description
# 1  myogenesis regulating glycosidase (putative)
# 2  myogenesis regulating glycosidase (putative)
# 3  myogenesis regulating glycosidase (putative)
# 4  myogenesis regulating glycosidase (putative)
# 5  myogenesis regulating glycosidase (putative)

# %%
slc20a2Xpr1 = slc20a2.merge(xpr1, how = 'inner', on = 'miRNA Name')
slc20a2Xpr1
# Out:
# 0  Target Detail_x Target Rank_x Target Score_x        miRNA Name  \
# 0          Details             2             99   hsa-miR-3613-3p
# 1          Details            15             92     hsa-miR-16-5p
# 2          Details            16             92    hsa-miR-15b-5p
# 3          Details            17             92    hsa-miR-15a-5p
# 4          Details            18             92    hsa-miR-195-5p
# 5          Details            20             91   hsa-miR-5585-5p
# 6          Details            24             90   hsa-miR-6838-5p
# 7          Details            25             90    hsa-miR-497-5p
# 8          Details            27             90    hsa-miR-424-5p
# 9          Details            28             88   hsa-miR-6878-5p
# 10         Details            30             87       hsa-miR-484
# 11         Details            33             85     hsa-miR-3155a
# 12         Details            34             85     hsa-miR-3155b
# 13         Details            39             80     hsa-miR-12136
# 14         Details            56             75   hsa-miR-513c-3p
# 15         Details            58             75   hsa-miR-193a-3p
# 16         Details            59             75   hsa-miR-193b-3p
# 17         Details            60             75   hsa-miR-513a-3p
# 18         Details            62             74   hsa-miR-3606-3p
# 19         Details            70             70   hsa-miR-6743-5p
# 20         Details            72             70      hsa-miR-4688
# 21         Details            74             69   hsa-miR-6810-3p
# 22         Details            75             69      hsa-miR-6131
# 23         Details            76             68  hsa-miR-548ao-5p
# 24         Details            77             68     hsa-miR-548ax
# 25         Details            81             65      hsa-miR-3163
# 26         Details            86             65      hsa-miR-4517
# 27         Details           110             58      hsa-miR-3148
# 28         Details           123             53   hsa-miR-200a-3p
# 29         Details           127             53    hsa-miR-141-3p
#
# 0  Gene Symbol_x                 Gene Description_x Target Detail_y  \
# 0        SLC20A2  solute carrier family 20 member 2         Details
# 1        SLC20A2  solute carrier family 20 member 2         Details
# 2        SLC20A2  solute carrier family 20 member 2         Details
# 3        SLC20A2  solute carrier family 20 member 2         Details
# 4        SLC20A2  solute carrier family 20 member 2         Details
# 5        SLC20A2  solute carrier family 20 member 2         Details
# 6        SLC20A2  solute carrier family 20 member 2         Details
# 7        SLC20A2  solute carrier family 20 member 2         Details
# 8        SLC20A2  solute carrier family 20 member 2         Details
# 9        SLC20A2  solute carrier family 20 member 2         Details
# 10       SLC20A2  solute carrier family 20 member 2         Details
# 11       SLC20A2  solute carrier family 20 member 2         Details
# 12       SLC20A2  solute carrier family 20 member 2         Details
# 13       SLC20A2  solute carrier family 20 member 2         Details
# 14       SLC20A2  solute carrier family 20 member 2         Details
# 15       SLC20A2  solute carrier family 20 member 2         Details
# 16       SLC20A2  solute carrier family 20 member 2         Details
# 17       SLC20A2  solute carrier family 20 member 2         Details
# 18       SLC20A2  solute carrier family 20 member 2         Details
# 19       SLC20A2  solute carrier family 20 member 2         Details
# 20       SLC20A2  solute carrier family 20 member 2         Details
# 21       SLC20A2  solute carrier family 20 member 2         Details
# 22       SLC20A2  solute carrier family 20 member 2         Details
# 23       SLC20A2  solute carrier family 20 member 2         Details
# 24       SLC20A2  solute carrier family 20 member 2         Details
# 25       SLC20A2  solute carrier family 20 member 2         Details
# 26       SLC20A2  solute carrier family 20 member 2         Details
# 27       SLC20A2  solute carrier family 20 member 2         Details
# 28       SLC20A2  solute carrier family 20 member 2         Details
# 29       SLC20A2  solute carrier family 20 member 2         Details
#
# 0  Target Rank_y Target Score_y Gene Symbol_y  \
# 0            114             72          XPR1
# 1            211             59          XPR1
# 2            208             59          XPR1
# 3            202             59          XPR1
# 4            201             59          XPR1
# 5            176             62          XPR1
# 6            198             59          XPR1
# 7            205             59          XPR1
# 8            203             59          XPR1
# 9             19             94          XPR1
# 10           212             58          XPR1
# 11           239             54          XPR1
# 12           240             54          XPR1
# 13             9             96          XPR1
# 14           150             68          XPR1
# 15           260             52          XPR1
# 16           265             52          XPR1
# 17           141             68          XPR1
# 18           152             68          XPR1
# 19           172             63          XPR1
# 20           180             62          XPR1
# 21           249             53          XPR1
# 22           200             59          XPR1
# 23           103             75          XPR1
# 24            98             75          XPR1
# 25           104             74          XPR1
# 26           105             74          XPR1
# 27            20             93          XPR1
# 28            25             92          XPR1
# 29            24             92          XPR1
#
# 0                                Gene Description_y
# 0   xenotropic and polytropic retrovirus receptor 1
# 1   xenotropic and polytropic retrovirus receptor 1
# 2   xenotropic and polytropic retrovirus receptor 1
# 3   xenotropic and polytropic retrovirus receptor 1
# 4   xenotropic and polytropic retrovirus receptor 1
# 5   xenotropic and polytropic retrovirus receptor 1
# 6   xenotropic and polytropic retrovirus receptor 1
# 7   xenotropic and polytropic retrovirus receptor 1
# 8   xenotropic and polytropic retrovirus receptor 1
# 9   xenotropic and polytropic retrovirus receptor 1
# 10  xenotropic and polytropic retrovirus receptor 1
# 11  xenotropic and polytropic retrovirus receptor 1
# 12  xenotropic and polytropic retrovirus receptor 1
# 13  xenotropic and polytropic retrovirus receptor 1
# 14  xenotropic and polytropic retrovirus receptor 1
# 15  xenotropic and polytropic retrovirus receptor 1
# 16  xenotropic and polytropic retrovirus receptor 1
# 17  xenotropic and polytropic retrovirus receptor 1
# 18  xenotropic and polytropic retrovirus receptor 1
# 19  xenotropic and polytropic retrovirus receptor 1
# 20  xenotropic and polytropic retrovirus receptor 1
# 21  xenotropic and polytropic retrovirus receptor 1
# 22  xenotropic and polytropic retrovirus receptor 1
# 23  xenotropic and polytropic retrovirus receptor 1
# 24  xenotropic and polytropic retrovirus receptor 1
# 25  xenotropic and polytropic retrovirus receptor 1
# 26  xenotropic and polytropic retrovirus receptor 1
# 27  xenotropic and polytropic retrovirus receptor 1
# 28  xenotropic and polytropic retrovirus receptor 1
# 29  xenotropic and polytropic retrovirus receptor 1

# %%
slc20a2Xpr1Myorg = slc20a2Xpr1.merge(myorg, how = 'inner', on = 'miRNA Name')
slc20a2Xpr1Myorg
# Out:
# 0 Target Detail_x Target Rank_x Target Score_x       miRNA Name Gene Symbol_x  \
# 0         Details            28             88  hsa-miR-6878-5p       SLC20A2
#
# 0                 Gene Description_x Target Detail_y Target Rank_y  \
# 0  solute carrier family 20 member 2         Details            19
#
# 0 Target Score_y Gene Symbol_y  \
# 0             94          XPR1
#
# 0                               Gene Description_y Target Detail Target Rank  \
# 0  xenotropic and polytropic retrovirus receptor 1       Details         171
#
# 0 Target Score Gene Symbol                              Gene Description
# 0           51       MYORG  myogenesis regulating glycosidase (putative)

# %%
slc20a2Myorg = slc20a2.merge(myorg, how = 'inner', on = 'miRNA Name')
slc20a2Myorg
# Out:
# 0 Target Detail_x Target Rank_x Target Score_x       miRNA Name Gene Symbol_x  \
# 0         Details            19             91   hsa-miR-340-5p       SLC20A2
# 1         Details            28             88  hsa-miR-6878-5p       SLC20A2
# 2         Details           103             60     hsa-miR-6132       SLC20A2
# 3         Details           104             60     hsa-miR-548s       SLC20A2
# 4         Details           111             58  hsa-miR-7157-5p       SLC20A2
# 5         Details           116             57     hsa-miR-4310       SLC20A2
# 6         Details           121             54     hsa-miR-4469       SLC20A2
#
# 0                 Gene Description_x Target Detail_y Target Rank_y  \
# 0  solute carrier family 20 member 2         Details            57
# 1  solute carrier family 20 member 2         Details           171
# 2  solute carrier family 20 member 2         Details           118
# 3  solute carrier family 20 member 2         Details           131
# 4  solute carrier family 20 member 2         Details            13
# 5  solute carrier family 20 member 2         Details            10
# 6  solute carrier family 20 member 2         Details            80
#
# 0 Target Score_y Gene Symbol_y                            Gene Description_y
# 0             74         MYORG  myogenesis regulating glycosidase (putative)
# 1             51         MYORG  myogenesis regulating glycosidase (putative)
# 2             59         MYORG  myogenesis regulating glycosidase (putative)
# 3             56         MYORG  myogenesis regulating glycosidase (putative)
# 4             92         MYORG  myogenesis regulating glycosidase (putative)
# 5             94         MYORG  myogenesis regulating glycosidase (putative)
# 6             69         MYORG  myogenesis regulating glycosidase (putative)

# %%
pdgfbPdgfrb = pdgfb.merge(pdgfrb, how = 'inner', on = 'miRNA Name')
pdgfbPdgfrb
# Out:
# 0  Target Detail_x Target Rank_x Target Score_x        miRNA Name  \
# 0          Details            20             83    hsa-miR-498-3p
# 1          Details            27             80      hsa-miR-4692
# 2          Details            64             63  hsa-miR-6780b-5p
# 3          Details            72             60   hsa-miR-6785-5p
# 4          Details            73             60   hsa-miR-4728-5p
# 5          Details            77             58   hsa-miR-4725-3p
# 6          Details            88             55   hsa-miR-6883-5p
# 7          Details            90             55    hsa-miR-363-5p
# 8          Details            92             55    hsa-miR-149-3p
# 9          Details            93             55      hsa-miR-6745
# 10         Details            94             55      hsa-miR-4441
#
# 0  Gene Symbol_x                        Gene Description_x Target Detail_y  \
# 0          PDGFB  platelet derived growth factor subunit B         Details
# 1          PDGFB  platelet derived growth factor subunit B         Details
# 2          PDGFB  platelet derived growth factor subunit B         Details
# 3          PDGFB  platelet derived growth factor subunit B         Details
# 4          PDGFB  platelet derived growth factor subunit B         Details
# 5          PDGFB  platelet derived growth factor subunit B         Details
# 6          PDGFB  platelet derived growth factor subunit B         Details
# 7          PDGFB  platelet derived growth factor subunit B         Details
# 8          PDGFB  platelet derived growth factor subunit B         Details
# 9          PDGFB  platelet derived growth factor subunit B         Details
# 10         PDGFB  platelet derived growth factor subunit B         Details
#
# 0  Target Rank_y Target Score_y Gene Symbol_y  \
# 0             37             73        PDGFRB
# 1             98             55        PDGFRB
# 2             79             59        PDGFRB
# 3             73             61        PDGFRB
# 4             68             61        PDGFRB
# 5             77             59        PDGFRB
# 6             72             61        PDGFRB
# 7             44             70        PDGFRB
# 8             71             61        PDGFRB
# 9             46             69        PDGFRB
# 10            22             82        PDGFRB
#
# 0                             Gene Description_y
# 0   platelet derived growth factor receptor beta
# 1   platelet derived growth factor receptor beta
# 2   platelet derived growth factor receptor beta
# 3   platelet derived growth factor receptor beta
# 4   platelet derived growth factor receptor beta
# 5   platelet derived growth factor receptor beta
# 6   platelet derived growth factor receptor beta
# 7   platelet derived growth factor receptor beta
# 8   platelet derived growth factor receptor beta
# 9   platelet derived growth factor receptor beta
# 10  platelet derived growth factor receptor beta

# %%
slc20a2Jam2 = slc20a2.merge(jam2, how = 'inner', on ='miRNA Name')
slc20a2Jam2
# Out:
# 0 Target Detail_x Target Rank_x Target Score_x        miRNA Name  \
# 0         Details             2             99   hsa-miR-3613-3p
# 1         Details            28             88   hsa-miR-6878-5p
# 2         Details            76             68  hsa-miR-548ao-5p
# 3         Details            77             68     hsa-miR-548ax
# 4         Details            85             65    hsa-miR-338-5p
# 5         Details            98             62   hsa-miR-548c-3p
# 6         Details           102             62      hsa-miR-6844
# 7         Details           118             56    hsa-miR-150-5p
# 8         Details           125             53    hsa-miR-197-3p
#
# 0 Gene Symbol_x                 Gene Description_x Target Detail_y  \
# 0       SLC20A2  solute carrier family 20 member 2         Details
# 1       SLC20A2  solute carrier family 20 member 2         Details
# 2       SLC20A2  solute carrier family 20 member 2         Details
# 3       SLC20A2  solute carrier family 20 member 2         Details
# 4       SLC20A2  solute carrier family 20 member 2         Details
# 5       SLC20A2  solute carrier family 20 member 2         Details
# 6       SLC20A2  solute carrier family 20 member 2         Details
# 7       SLC20A2  solute carrier family 20 member 2         Details
# 8       SLC20A2  solute carrier family 20 member 2         Details
#
# 0 Target Rank_y Target Score_y Gene Symbol_y              Gene Description_y
# 0            63             64          JAM2  junctional adhesion molecule 2
# 1           112             54          JAM2  junctional adhesion molecule 2
# 2           119             53          JAM2  junctional adhesion molecule 2
# 3           121             53          JAM2  junctional adhesion molecule 2
# 4             7             92          JAM2  junctional adhesion molecule 2
# 5            46             70          JAM2  junctional adhesion molecule 2
# 6            19             82          JAM2  junctional adhesion molecule 2
# 7            89             57          JAM2  junctional adhesion molecule 2
# 8            60             65          JAM2  junctional adhesion molecule 2

# %%
def sharedTarget(gene1, gene2):
    sharedmiRNAs = []
    geneOne = gene1['Gene Symbol'][1]
    geneTwo = gene2['Gene Symbol'][1]
    for miRNA in enumerate(gene1['miRNA Name']):
        if miRNA[1] in gene2['miRNA Name'].unique():
            targetScore1 = int(gene1['Target Score'].iloc[miRNA[0]])
            targetScore2 = int(gene2[gene2['miRNA Name'].str.contains(miRNA[1])]['Target Score'])
            aveScore = int((targetScore1 + targetScore2) / 2)
            sharedmiRNAs.append([miRNA[1], geneOne, targetScore1, geneTwo, targetScore2, aveScore])
    return sharedmiRNAs

# %%
sharedTarget(slc20a2,xpr1)
# Out:
# [['hsa-miR-3613-3p', 'SLC20A2', 99, 'XPR1', 72, 85],
#  ['hsa-miR-16-5p', 'SLC20A2', 92, 'XPR1', 59, 75],
#  ['hsa-miR-15b-5p', 'SLC20A2', 92, 'XPR1', 59, 75],
#  ['hsa-miR-15a-5p', 'SLC20A2', 92, 'XPR1', 59, 75],
#  ['hsa-miR-195-5p', 'SLC20A2', 92, 'XPR1', 59, 75],
#  ['hsa-miR-5585-5p', 'SLC20A2', 91, 'XPR1', 62, 76],
#  ['hsa-miR-6838-5p', 'SLC20A2', 90, 'XPR1', 59, 74],
#  ['hsa-miR-497-5p', 'SLC20A2', 90, 'XPR1', 59, 74],
#  ['hsa-miR-424-5p', 'SLC20A2', 90, 'XPR1', 59, 74],
#  ['hsa-miR-6878-5p', 'SLC20A2', 88, 'XPR1', 94, 91],
#  ['hsa-miR-484', 'SLC20A2', 87, 'XPR1', 58, 72],
#  ['hsa-miR-3155a', 'SLC20A2', 85, 'XPR1', 54, 69],
#  ['hsa-miR-3155b', 'SLC20A2', 85, 'XPR1', 54, 69],
#  ['hsa-miR-12136', 'SLC20A2', 80, 'XPR1', 96, 88],
#  ['hsa-miR-513c-3p', 'SLC20A2', 75, 'XPR1', 68, 71],
#  ['hsa-miR-193a-3p', 'SLC20A2', 75, 'XPR1', 52, 63],
#  ['hsa-miR-193b-3p', 'SLC20A2', 75, 'XPR1', 52, 63],
#  ['hsa-miR-513a-3p', 'SLC20A2', 75, 'XPR1', 68, 71],
#  ['hsa-miR-3606-3p', 'SLC20A2', 74, 'XPR1', 68, 71],
#  ['hsa-miR-6743-5p', 'SLC20A2', 70, 'XPR1', 63, 66],
#  ['hsa-miR-4688', 'SLC20A2', 70, 'XPR1', 62, 66],
#  ['hsa-miR-6810-3p', 'SLC20A2', 69, 'XPR1', 53, 61],
#  ['hsa-miR-6131', 'SLC20A2', 69, 'XPR1', 59, 64],
#  ['hsa-miR-548ao-5p', 'SLC20A2', 68, 'XPR1', 75, 71],
#  ['hsa-miR-548ax', 'SLC20A2', 68, 'XPR1', 75, 71],
#  ['hsa-miR-3163', 'SLC20A2', 65, 'XPR1', 74, 69],
#  ['hsa-miR-4517', 'SLC20A2', 65, 'XPR1', 74, 69],
#  ['hsa-miR-3148', 'SLC20A2', 58, 'XPR1', 93, 75],
#  ['hsa-miR-200a-3p', 'SLC20A2', 53, 'XPR1', 92, 72],
#  ['hsa-miR-141-3p', 'SLC20A2', 53, 'XPR1', 92, 72]]

# %%
geneList = [slc20a2, xpr1, pdgfb, pdgfrb, jam2, myorg]
miRPFBC = dict()

for i in range(len(geneList)-1):
    count = len(geneList)-1-i
    while count > 0:
        miRNAs = sharedTarget(geneList[i],geneList[count])
        geneOne = miRNAs[0][1]
        geneTwo = miRNAs[0][3]
        if geneOne == geneTwo:
            count -= 1
        else:
            key = str(str(geneOne) + str(geneTwo))
            miRPFBC[key] = miRNAs
            count -= 1

# %%
miRPFBC.keys()
# Out:
# dict_keys(['SLC20A2MYORG', 'SLC20A2JAM2', 'SLC20A2PDGFRB', 'SLC20A2PDGFB', 'SLC20A2XPR1', 'XPR1JAM2', 'XPR1PDGFRB', 'XPR1PDGFB', 'PDGFBPDGFRB', 'PDGFBXPR1', 'PDGFRBPDGFB', 'PDGFRBXPR1', 'JAM2XPR1'])

# %%
df = pd.DataFrame.from_dict(miRPFBC['SLC20A2MYORG'])
df.columns = ['miRNA', 'G1', 'G1 Target Score', 'G2', 'G2 Target Score', 'Average']
df.sort_values(['Average'], ascending = False)
df
# Out:
#              miRNA       G1  G1 Target Score     G2  G2 Target Score  Average
# 0   hsa-miR-340-5p  SLC20A2               91  MYORG               74       82
# 1  hsa-miR-6878-5p  SLC20A2               88  MYORG               51       69
# 2     hsa-miR-6132  SLC20A2               60  MYORG               59       59
# 3     hsa-miR-548s  SLC20A2               60  MYORG               56       58
# 4  hsa-miR-7157-5p  SLC20A2               58  MYORG               92       75
# 5     hsa-miR-4310  SLC20A2               57  MYORG               94       75
# 6     hsa-miR-4469  SLC20A2               54  MYORG               69       61

# %%
for key in miRPFBC:
    df = pd.DataFrame.from_dict(miRPFBC[key])
    df.columns = ['miRNA', 'G1', 'G1 Target Score', 'G2', 'G2 Target Score', 'Average']
    df.sort_values(['Average'], ascending = False)
    df.to_csv('%s.csv' % key)
    print(df)
# Out:
#              miRNA       G1  G1 Target Score     G2  G2 Target Score  Average
# 0   hsa-miR-340-5p  SLC20A2               91  MYORG               74       82
# 1  hsa-miR-6878-5p  SLC20A2               88  MYORG               51       69
# 2     hsa-miR-6132  SLC20A2               60  MYORG               59       59
# 3     hsa-miR-548s  SLC20A2               60  MYORG               56       58
# 4  hsa-miR-7157-5p  SLC20A2               58  MYORG               92       75
# 5     hsa-miR-4310  SLC20A2               57  MYORG               94       75
# 6     hsa-miR-4469  SLC20A2               54  MYORG               69       61
#               miRNA       G1  G1 Target Score    G2  G2 Target Score  Average
# 0   hsa-miR-3613-3p  SLC20A2               99  JAM2               64       81
# 1   hsa-miR-6878-5p  SLC20A2               88  JAM2               54       71
# 2  hsa-miR-548ao-5p  SLC20A2               68  JAM2               53       60
# 3     hsa-miR-548ax  SLC20A2               68  JAM2               53       60
# 4    hsa-miR-338-5p  SLC20A2               65  JAM2               92       78
# 5   hsa-miR-548c-3p  SLC20A2               62  JAM2               70       66
# 6      hsa-miR-6844  SLC20A2               62  JAM2               82       72
# 7    hsa-miR-150-5p  SLC20A2               56  JAM2               57       56
# 8    hsa-miR-197-3p  SLC20A2               53  JAM2               65       59
#               miRNA       G1  G1 Target Score      G2  G2 Target Score  \
# 0   hsa-miR-3184-5p  SLC20A2               93  PDGFRB               67
# 1    hsa-miR-423-5p  SLC20A2               93  PDGFRB               67
# 2      hsa-miR-9-5p  SLC20A2               90  PDGFRB               92
# 3    hsa-miR-889-3p  SLC20A2               88  PDGFRB               52
# 4     hsa-miR-12136  SLC20A2               80  PDGFRB               64
# 5      hsa-miR-4441  SLC20A2               80  PDGFRB               82
# 6   hsa-miR-6754-5p  SLC20A2               76  PDGFRB               67
# 7      hsa-miR-4270  SLC20A2               76  PDGFRB               67
# 8      hsa-miR-1263  SLC20A2               65  PDGFRB               90
# 9    hsa-miR-150-3p  SLC20A2               65  PDGFRB               76
# 10     hsa-miR-548n  SLC20A2               65  PDGFRB               75
# 11     hsa-miR-4672  SLC20A2               63  PDGFRB               73
# 12  hsa-miR-7157-5p  SLC20A2               58  PDGFRB               54
# 13     hsa-miR-4310  SLC20A2               57  PDGFRB               67
# 14     hsa-miR-2861  SLC20A2               51  PDGFRB               63
#
#     Average
# 0        80
# 1        80
# 2        91
# 3        70
# 4        72
# 5        81
# 6        71
# 7        71
# 8        77
# 9        70
# 10       70
# 11       68
# 12       56
# 13       62
# 14       57
#              miRNA       G1  G1 Target Score     G2  G2 Target Score  Average
# 0     hsa-miR-4441  SLC20A2               80  PDGFB               55       67
# 1     hsa-miR-3202  SLC20A2               73  PDGFB               70       71
# 2     hsa-miR-5194  SLC20A2               63  PDGFB               50       56
# 3  hsa-miR-6738-5p  SLC20A2               62  PDGFB               50       56
# 4   hsa-miR-767-5p  SLC20A2               57  PDGFB               63       60
#                miRNA       G1  G1 Target Score    G2  G2 Target Score  Average
# 0    hsa-miR-3613-3p  SLC20A2               99  XPR1               72       85
# 1      hsa-miR-16-5p  SLC20A2               92  XPR1               59       75
# 2     hsa-miR-15b-5p  SLC20A2               92  XPR1               59       75
# 3     hsa-miR-15a-5p  SLC20A2               92  XPR1               59       75
# 4     hsa-miR-195-5p  SLC20A2               92  XPR1               59       75
# 5    hsa-miR-5585-5p  SLC20A2               91  XPR1               62       76
# 6    hsa-miR-6838-5p  SLC20A2               90  XPR1               59       74
# 7     hsa-miR-497-5p  SLC20A2               90  XPR1               59       74
# 8     hsa-miR-424-5p  SLC20A2               90  XPR1               59       74
# 9    hsa-miR-6878-5p  SLC20A2               88  XPR1               94       91
# 10       hsa-miR-484  SLC20A2               87  XPR1               58       72
# 11     hsa-miR-3155a  SLC20A2               85  XPR1               54       69
# 12     hsa-miR-3155b  SLC20A2               85  XPR1               54       69
# 13     hsa-miR-12136  SLC20A2               80  XPR1               96       88
# 14   hsa-miR-513c-3p  SLC20A2               75  XPR1               68       71
# 15   hsa-miR-193a-3p  SLC20A2               75  XPR1               52       63
# 16   hsa-miR-193b-3p  SLC20A2               75  XPR1               52       63
# 17   hsa-miR-513a-3p  SLC20A2               75  XPR1               68       71
# 18   hsa-miR-3606-3p  SLC20A2               74  XPR1               68       71
# 19   hsa-miR-6743-5p  SLC20A2               70  XPR1               63       66
# 20      hsa-miR-4688  SLC20A2               70  XPR1               62       66
# 21   hsa-miR-6810-3p  SLC20A2               69  XPR1               53       61
# 0   hsa-miR-10393-5p  JAM2               87  XPR1               66       76
# 1        hsa-miR-527  JAM2               83  XPR1               82       82
# 2     hsa-miR-382-5p  JAM2               83  XPR1               70       76
# 3    hsa-miR-518a-5p  JAM2               83  XPR1               82       82
# 4     hsa-miR-877-3p  JAM2               82  XPR1               70       76
# 5       hsa-miR-3149  JAM2               79  XPR1               57       68
# 6       hsa-miR-3662  JAM2               78  XPR1               82       80
# 7    hsa-miR-548d-3p  JAM2               76  XPR1               83       79
# 8    hsa-miR-548h-3p  JAM2               76  XPR1               83       79
# 9   hsa-miR-548bb-3p  JAM2               76  XPR1               83       79
# 10      hsa-miR-548z  JAM2               76  XPR1               83       79
# 11     hsa-miR-548ac  JAM2               76  XPR1               83       79
# 12    hsa-miR-373-5p  JAM2               68  XPR1               75       71
# 13    hsa-miR-616-5p  JAM2               68  XPR1               75       71
# 14   hsa-miR-371b-5p  JAM2               68  XPR1               75       71
# 15   hsa-miR-3613-3p  JAM2               64  XPR1               72       68
# 16     hsa-miR-12124  JAM2               63  XPR1               57       60
# 17   hsa-miR-7154-5p  JAM2               61  XPR1               92       76
# 18  hsa-miR-4524a-3p  JAM2               60  XPR1               60       60
# 19    hsa-miR-30d-5p  JAM2               57  XPR1               96       76
# 20    hsa-miR-30c-5p  JAM2               57  XPR1               96       76
# 21    hsa-miR-30e-5p  JAM2               57  XPR1               96       76
# 22    hsa-miR-30b-5p  JAM2               57  XPR1               96       76
# 23   hsa-miR-6824-5p  JAM2               57  XPR1               57       57
# 24    hsa-miR-30a-5p  JAM2               57  XPR1               96       76
# 25      hsa-miR-7977  JAM2               54  XPR1               63       58
# 26   hsa-miR-6878-5p  JAM2               54  XPR1               94       74
# 27  hsa-miR-548ao-5p  JAM2               53  XPR1               75       64
# 28     hsa-miR-548ax  JAM2               53  XPR1               75       64
# 29   hsa-miR-548t-3p  JAM2               51  XPR1               78       64
# 30     hsa-miR-548aa  JAM2               51  XPR1               78       64
# 31  hsa-miR-548ap-3p  JAM2               51  XPR1               78       64

# %%
listOfMiRs = []
for key in miRPFBC:
    for miR in miRPFBC[key]:
        if miR[5] > 80:
            listOfMiRs.append(miR[:5])
            
with open('miRs.txt', 'w') as f:
    for miR in listOfMiRs:
        f.write("%s\n" % miR)

# %%
isunique = []
for miR in listOfMiRs:
    if miR[0] in isunique:
        continue
    else:
        isunique.append(miR[0])
print(isunique) 
print(len(isunique))
# Out:
# ['hsa-miR-340-5p', 'hsa-miR-3613-3p', 'hsa-miR-9-5p', 'hsa-miR-4441', 'hsa-miR-6878-5p', 'hsa-miR-12136', 'hsa-miR-518a-5p', 'hsa-miR-527', 'hsa-miR-30d-5p', 'hsa-miR-30a-5p', 'hsa-miR-30c-5p', 'hsa-miR-30e-5p', 'hsa-miR-30b-5p', 'hsa-miR-1252-5p', 'hsa-miR-5692a', 'hsa-miR-1289', 'hsa-miR-6880-5p']
# 17
